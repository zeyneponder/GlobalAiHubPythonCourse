# %%
total_points=0

ans_1=input("Q1 : Language that ends with 'thon'?")
if (ans_1).lower()=="python":
    total_points+=10
else:
    pass

ans_2=input("Q2 : 15/3 ?")
if ans_2==5:
    total_points+=10
else:
    pass
    
ans_3=input("Q3 : What is 'str' in python?")
if (ans_3).lower()=="string":
    total_points+=10
else:
    pass

ans_4=input("Q4 : What is 'int' in python?")
if (ans_4).lower()=="integer":
    total_points+=10
else:
    pass

ans_5=input("Q5 : Is python object oriented?")
if (ans_5).lower()=="yes":
    total_points+=10
else:
    pass

ans_6=input("Q6 : How to write 'Cascading Style Sheets' in short?")
if (ans_6).lower()=="css":
    total_points+=10
else:
    pass
    
ans_7=input("Q7 : 25*4 ?")
if ans_7==100:
    total_points+=10
else:
    pass

ans_8=input("Q8 : What is the capital city of Turkey ?")
if (ans_8).lower()=="ankara":
    total_points+=10
else:
    pass

ans_9=input("Q9 : 4*0 ?")
if ans_9==0:
    total_points+=10
else:
    pass

ans_10=input("Q10 : 25*2-1 ?")
if ans_10==49:
    total_points+=10
else:
    pass

if total_points<=50:
    print("unsuccesfull")
else:
    print("succesfull")
